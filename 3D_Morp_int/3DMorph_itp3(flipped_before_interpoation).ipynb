# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import random

def goto(linenum):
    global line
    line = linenum

ch = pd.read_csv("Ch_ele.txt", delim_whitespace=True,
          header=None, names=["Elev","Index"])
tr = pd.read_csv("trace.txt", delim_whitespace=True,
          header=None, names=["GPR_points"])

N = 110
max = 0

size = np.zeros(shape=(N), dtype=int)
size2 = np.zeros(shape=(N), dtype=int)

for i in np.arange(1,N+1,1):
    tm = ch.loc[ch["Index"]==str(i),["Elev"]]
    size[i-1] = np.size(tm)
    
max = np.max(size)
    
print("max number of GNSS points",max)

for i in np.arange(1,N+1,1):
    size2[i-1] = tr["GPR_points"][i-1]
#    print(size2[i-1])
min = np.min(size2)
print("min number of GPR points",min)

#The shape of final output
Elev_ch4 = np.zeros(shape=(N,min))
Elev_ch5 = np.zeros(shape=(N,min))
# Out:
# max number of GNSS points 147
# min number of GPR points 1498

# %%
GNSS = np.zeros(shape=(N,max))
GNSS_tm = np.zeros(shape=(N,max))

for n in np.arange(1,N+1,1):

    print("++++++")
    print("n=",n)
    print("++++++")
    tm = ch.loc[ch["Index"]==str(n),["Elev"]]
    tm_size = np.size(tm)
    print("\"tm_size\" means the number of GNSS points")
    print("tm_size=",tm_size)
#    print(tm)
    for j in np.arange(0,tm_size,1):
        GNSS[n-1][j] = tm["Elev"][j+sum(size[:(n-1)])]

    if((n-1) % 2 != 0):
        for f in np.arange(0,tm_size,1):
            GNSS_tm[n-1][((tm_size-1)-f)] = GNSS[n-1][f]
        
        GNSS[n-1][:] = GNSS_tm[n-1][:]

###############################################################
    G_point = tr["GPR_points"][n-1]
    print("G_point=",G_point)

    Elev_ch2 = np.zeros(shape=(G_point))
    Elev_ch3 = np.zeros(shape=(G_point))
    Elev_tm = np.zeros(shape=(G_point))

    tm2 = np.zeros(shape=G_point)

    print("Elev_ch2=",np.size(Elev_ch2))    

    print("G_point/tm_size",G_point/tm_size)
    print("itv=math.ceil(G_point/tm_size) ")
    itv = math.ceil(G_point/tm_size)   #   
    print("itv=",itv)
    
    tm_size2 = math.floor(G_point/itv)
    print("tm_size2=math.floor(G_point/itv)")
    print("tm_size2=",tm_size2)
    
    M = tm_size2 * itv 
    print("M=",M)
                
    for j in np.arange(0,tm_size2+1,1):       
#        print("j=",j,"j+itv=",j*itv, "GNSS=",GNSS[n-1][j]) #Do not remove this sentence!!
        if(j*itv >= G_point):
            break
        Elev_ch2[j*itv] = GNSS[n-1][j]
        Elev_ch3[j*itv] = GNSS[n-1][j]        
###############################################################    
    for j in np.arange(itv,(tm_size2+1)*itv,itv):    
#    for j in np.arange(itv,(tm_size2*itv),itv):    

#        print(j)

        if (j == G_point and GNSS[n-1][tm_size2+1] != 0.0 ):
            Elev_ch2[j-1] = GNSS[n-1][tm_size2+1] 
            print("j == G_point","j=",j,"Elev_ch2[",j-1,"]=",Elev_ch2[j-1])

            for i in np.arange(1,itv,1):
                j2 = j- 1
                
                Elev_ch2[(j2-itv)+i] = Elev_ch2[j2-itv] + ( (i*0.05) * (Elev_ch2[j2] - Elev_ch2[j2-itv])/(0.05 * itv) )
        elif(j < G_point):
  
            for i in np.arange(1,itv,1):
                Elev_ch2[(j-itv)+i] = Elev_ch2[j-itv] + ( (i*0.05) * (Elev_ch2[j] - Elev_ch2[j-itv])/(0.05 * itv) )

        elif(j == G_point and GNSS[n-1][tm_size2+1] == 0.0 ):          
            Elev_ch2[j-1] = random.uniform(GNSS[n-1][tm_size2-2],GNSS[n-1][tm_size2-1])
            print(GNSS[n-1][tm_size2-2],GNSS[n-1][tm_size2-1])
            print(Elev_ch2[j-1])
            for i in np.arange(1,itv,1):
                j2 = j- 1
#                print("Elev_ch2[",j2,"], Elev_ch2[",j2-itv,"]=",Elev_ch2[j2], Elev_ch2[j2-itv])
                Elev_ch2[(j2-itv)+i] = Elev_ch2[j2-itv] + ( (i*0.05) * (Elev_ch2[j2] - Elev_ch2[j2-itv])/(0.05 * itv) )
#                print("j2-itv+i=",j2-itv+i,Elev_ch2[(j2-itv)+i])

###############################################################    
    if(M == G_point):
        goto(90)
    else:    
        print("else")
        Elev_ch2[G_point-1] = GNSS[n-1][tm_size-1]
 #       Elev_ch2[G_point-1] = GNSS[n-1][tm_size2+2]
        itv2 = (G_point-1)- M
        print("itv2 = (G_point-1)- M =",itv2)
        print("M = tm_size2 * itv =", M)
        print("Elev_ch2[",M,"]",Elev_ch2[M])
        print("Elev_ch2[",G_point-1,"]",Elev_ch2[G_point-1])
        
        for i in np.arange(1,itv2+1,1):          
            Elev_ch2[M+i] = Elev_ch2[M] + ( (i * 0.05) * (Elev_ch2[G_point-1] - Elev_ch2[M])/(0.05 * itv2) )       
                
###############################################################    
#flip the track at each odd track
#    if((n-1) % 2 != 0) :
#        print (Elev_ch2[3])
        
#        print (Elev_ch3[-4])

    for j in np.arange(0,min,1):
        Elev_ch4[n-1][j] = Elev_ch2[j]
#        if((n-1) % 2 != 0):
#            Elev_ch3[:] = np.flipud(Elev_ch2[:])           
#            Elev_ch4[n-1][j] = Elev_ch3[j]
            
         
#            print(n-1,"flip")
        
#    for j in np.arange(0,min,1):
#        Elev_ch5[n-1][j] = Elev_ch2[j]    
                 
###############################################################    
    plt.plot(Elev_ch2,"o")
#    plt.plot(Elev_ch2[1479:1513],"o")    
#    plt.ylim(1602,1608)
    plt.legend(["51","52"])
# Out:
# ++++++
# n= 1
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 87
# G_point= 1547
# Elev_ch2= 1547
# G_point/tm_size 17.7816091954023
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 85
# M= 1530
# else
# itv2 = (G_point-1)- M = 16
# M = tm_size2 * itv = 1530
# Elev_ch2[ 1530 ] 1607.671
# Elev_ch2[ 1546 ] 1607.675
# ++++++
# n= 2
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 72
# G_point= 1511
# Elev_ch2= 1511
# G_point/tm_size 20.98611111111111
# itv=math.ceil(G_point/tm_size)
# itv= 21
# tm_size2=math.floor(G_point/itv)
# tm_size2= 71
# M= 1491
# else
# itv2 = (G_point-1)- M = 19
# M = tm_size2 * itv = 1491
# Elev_ch2[ 1491 ] 1607.515
# Elev_ch2[ 1510 ] 1607.515
# ++++++
# n= 3
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 59
# G_point= 1545
# Elev_ch2= 1545
# G_point/tm_size 26.1864406779661
# itv=math.ceil(G_point/tm_size)
# itv= 27
# tm_size2=math.floor(G_point/itv)
# tm_size2= 57
# M= 1539
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1607.411
# Elev_ch2[ 1544 ] 1607.403
# ++++++
# n= 4
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 61
# G_point= 1509
# Elev_ch2= 1509
# G_point/tm_size 24.737704918032787
# itv=math.ceil(G_point/tm_size)
# itv= 25
# tm_size2=math.floor(G_point/itv)
# tm_size2= 60
# M= 1500
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1500
# Elev_ch2[ 1500 ] 1607.27
# Elev_ch2[ 1508 ] 1607.27
# ++++++
# n= 5
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 58
# G_point= 1546
# Elev_ch2= 1546
# G_point/tm_size 26.655172413793103
# itv=math.ceil(G_point/tm_size)
# itv= 27
# tm_size2=math.floor(G_point/itv)
# tm_size2= 57
# M= 1539
# else
# itv2 = (G_point-1)- M = 6
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1607.151
# Elev_ch2[ 1545 ] 1607.151
# ++++++
# n= 6
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 69
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 21.840579710144926
# itv=math.ceil(G_point/tm_size)
# itv= 22
# tm_size2=math.floor(G_point/itv)
# tm_size2= 68
# M= 1496
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1496
# Elev_ch2[ 1496 ] 1607.029
# Elev_ch2[ 1506 ] 1607.029
# ++++++
# n= 7
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 88
# G_point= 1544
# Elev_ch2= 1544
# G_point/tm_size 17.545454545454547
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 85
# M= 1530
# else
# itv2 = (G_point-1)- M = 13
# M = tm_size2 * itv = 1530
# Elev_ch2[ 1530 ] 1606.945
# Elev_ch2[ 1543 ] 1606.935
# ++++++
# n= 8
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 108
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 13.953703703703704
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 107
# M= 1498
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1498
# Elev_ch2[ 1498 ] 1606.78
# Elev_ch2[ 1506 ] 1606.78
# ++++++
# n= 9
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 91
# G_point= 1543
# Elev_ch2= 1543
# G_point/tm_size 16.956043956043956
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 90
# M= 1530
# else
# itv2 = (G_point-1)- M = 12
# M = tm_size2 * itv = 1530
# Elev_ch2[ 1530 ] 1606.691
# Elev_ch2[ 1542 ] 1606.691
# ++++++
# n= 10
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 108
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 13.953703703703704
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 107
# M= 1498
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1498
# Elev_ch2[ 1498 ] 1606.562
# Elev_ch2[ 1506 ] 1606.562
# ++++++
# n= 11
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 116
# G_point= 1543
# Elev_ch2= 1543
# G_point/tm_size 13.301724137931034
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1606.315
# Elev_ch2[ 1542 ] 1606.465
# ++++++
# n= 12
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 147
# G_point= 1509
# Elev_ch2= 1509
# G_point/tm_size 10.26530612244898
# itv=math.ceil(G_point/tm_size)
# itv= 11
# tm_size2=math.floor(G_point/itv)
# tm_size2= 137
# M= 1507
# else
# itv2 = (G_point-1)- M = 1
# M = tm_size2 * itv = 1507
# Elev_ch2[ 1507 ] 1606.194
# Elev_ch2[ 1508 ] 1606.304
# ++++++
# n= 13
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 124
# G_point= 1539
# Elev_ch2= 1539
# G_point/tm_size 12.411290322580646
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 118
# M= 1534
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1534
# Elev_ch2[ 1534 ] 1606.134
# Elev_ch2[ 1538 ] 1606.224
# ++++++
# n= 14
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 116
# G_point= 1505
# Elev_ch2= 1505
# G_point/tm_size 12.974137931034482
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 115
# M= 1495
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1495
# Elev_ch2[ 1495 ] 1606.06
# Elev_ch2[ 1504 ] 1606.06
# ++++++
# n= 15
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 147
# G_point= 1547
# Elev_ch2= 1547
# G_point/tm_size 10.523809523809524
# itv=math.ceil(G_point/tm_size)
# itv= 11
# tm_size2=math.floor(G_point/itv)
# tm_size2= 140
# M= 1540
# else
# itv2 = (G_point-1)- M = 6
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1605.9
# Elev_ch2[ 1546 ] 1605.958
# ++++++
# n= 16
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 140
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 10.764285714285714
# itv=math.ceil(G_point/tm_size)
# itv= 11
# tm_size2=math.floor(G_point/itv)
# tm_size2= 137
# M= 1507
# j == G_point j= 1507 Elev_ch2[ 1506 ]= 1605.843
# ++++++
# n= 17
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 141
# G_point= 1541
# Elev_ch2= 1541
# G_point/tm_size 10.929078014184396
# itv=math.ceil(G_point/tm_size)
# itv= 11
# tm_size2=math.floor(G_point/itv)
# tm_size2= 140
# M= 1540
# else
# itv2 = (G_point-1)- M = 0
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1605.703
# Elev_ch2[ 1540 ] 1605.703
# ++++++
# n= 18
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 116
# G_point= 1511
# Elev_ch2= 1511
# G_point/tm_size 13.025862068965518
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 107
# M= 1498
# else
# itv2 = (G_point-1)- M = 12
# M = tm_size2 * itv = 1498
# Elev_ch2[ 1498 ] 1605.48
# Elev_ch2[ 1510 ] 1605.597
# ++++++
# n= 19
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 112
# G_point= 1546
# Elev_ch2= 1546
# G_point/tm_size 13.803571428571429
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1605.487
# Elev_ch2[ 1545 ] 1605.478
# ++++++
# n= 20
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 122
# G_point= 1514
# Elev_ch2= 1514
# G_point/tm_size 12.40983606557377
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 116
# M= 1508
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1508
# Elev_ch2[ 1508 ] 1605.344
# Elev_ch2[ 1513 ] 1605.371
# ++++++
# n= 21
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 135
# G_point= 1546
# Elev_ch2= 1546
# G_point/tm_size 11.451851851851853
# itv=math.ceil(G_point/tm_size)
# itv= 12
# tm_size2=math.floor(G_point/itv)
# tm_size2= 128
# M= 1536
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1536
# Elev_ch2[ 1536 ] 1605.188
# Elev_ch2[ 1545 ] 1605.277
# ++++++
# n= 22
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 107
# G_point= 1518
# Elev_ch2= 1518
# G_point/tm_size 14.186915887850468
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1515
# Elev_ch2[ 1515 ] 1605.079
# Elev_ch2[ 1517 ] 1605.159
# ++++++
# n= 23
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 122
# G_point= 1549
# Elev_ch2= 1549
# G_point/tm_size 12.69672131147541
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 119
# M= 1547
# else
# itv2 = (G_point-1)- M = 1
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1605.082
# Elev_ch2[ 1548 ] 1605.073
# ++++++
# n= 24
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 133
# G_point= 1516
# Elev_ch2= 1516
# G_point/tm_size 11.398496240601503
# itv=math.ceil(G_point/tm_size)
# itv= 12
# tm_size2=math.floor(G_point/itv)
# tm_size2= 126
# M= 1512
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1604.927
# Elev_ch2[ 1515 ] 1604.916
# ++++++
# n= 25
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 116
# G_point= 1546
# Elev_ch2= 1546
# G_point/tm_size 13.327586206896552
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1604.722
# Elev_ch2[ 1545 ] 1604.787
# ++++++
# n= 26
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 124
# G_point= 1498
# Elev_ch2= 1498
# G_point/tm_size 12.080645161290322
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 115
# M= 1495
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1495
# Elev_ch2[ 1495 ] 1604.642
# Elev_ch2[ 1497 ] 1604.742
# ++++++
# n= 27
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 119
# G_point= 1541
# Elev_ch2= 1541
# G_point/tm_size 12.949579831932773
# itv=math.ceil(G_point/tm_size)
# itv= 13
# tm_size2=math.floor(G_point/itv)
# tm_size2= 118
# M= 1534
# else
# itv2 = (G_point-1)- M = 6
# M = tm_size2 * itv = 1534
# Elev_ch2[ 1534 ] 1604.603
# Elev_ch2[ 1540 ] 1604.603
# ++++++
# n= 28
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 109
# G_point= 1508
# Elev_ch2= 1508
# G_point/tm_size 13.8348623853211
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 107
# M= 1498
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1498
# Elev_ch2[ 1498 ] 1604.455
# Elev_ch2[ 1507 ] 1604.467
# ++++++
# n= 29
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 111
# G_point= 1544
# Elev_ch2= 1544
# G_point/tm_size 13.90990990990991
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1604.373
# Elev_ch2[ 1543 ] 1604.373
# ++++++
# n= 30
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 113
# G_point= 1502
# Elev_ch2= 1502
# G_point/tm_size 13.29203539823009
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 107
# M= 1498
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1498
# Elev_ch2[ 1498 ] 1604.183
# Elev_ch2[ 1501 ] 1604.276
# ++++++
# n= 31
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 112
# G_point= 1540
# Elev_ch2= 1540
# G_point/tm_size 13.75
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# j == G_point j= 1540 Elev_ch2[ 1539 ]= 1604.172
# ++++++
# n= 32
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 96
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 15.697916666666666
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 94
# M= 1504
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1504
# Elev_ch2[ 1504 ] 1604.09
# Elev_ch2[ 1506 ] 1604.087
# ++++++
# n= 33
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 85
# G_point= 1541
# Elev_ch2= 1541
# G_point/tm_size 18.129411764705882
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 81
# M= 1539
# else
# itv2 = (G_point-1)- M = 1
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1603.908
# Elev_ch2[ 1540 ] 1603.971
# ++++++
# n= 34
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 98
# G_point= 1512
# Elev_ch2= 1512
# G_point/tm_size 15.428571428571429
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 94
# M= 1504
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1504
# Elev_ch2[ 1504 ] 1603.827
# Elev_ch2[ 1511 ] 1603.856
# ++++++
# n= 35
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 91
# G_point= 1544
# Elev_ch2= 1544
# G_point/tm_size 16.967032967032967
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 90
# M= 1530
# else
# itv2 = (G_point-1)- M = 13
# M = tm_size2 * itv = 1530
# Elev_ch2[ 1530 ] 1603.8
# Elev_ch2[ 1543 ] 1603.8
# ++++++
# n= 36
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 93
# G_point= 1507
# Elev_ch2= 1507
# G_point/tm_size 16.204301075268816
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 88
# M= 1496
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1496
# Elev_ch2[ 1496 ] 1603.608
# Elev_ch2[ 1506 ] 1603.697
# ++++++
# n= 37
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 99
# G_point= 1544
# Elev_ch2= 1544
# G_point/tm_size 15.595959595959595
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 96
# M= 1536
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1536
# Elev_ch2[ 1536 ] 1603.573
# Elev_ch2[ 1543 ] 1603.574
# ++++++
# n= 38
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 90
# G_point= 1513
# Elev_ch2= 1513
# G_point/tm_size 16.81111111111111
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 89
# M= 1513
# 1603.472 1603.483
# 1603.4817931864181
# ++++++
# n= 39
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 89
# G_point= 1548
# Elev_ch2= 1548
# G_point/tm_size 17.39325842696629
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 86
# M= 1548
# j == G_point j= 1548 Elev_ch2[ 1547 ]= 1603.394
# ++++++
# n= 40
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 99
# G_point= 1519
# Elev_ch2= 1519
# G_point/tm_size 15.343434343434344
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 94
# M= 1504
# else
# itv2 = (G_point-1)- M = 14
# M = tm_size2 * itv = 1504
# Elev_ch2[ 1504 ] 1603.201
# Elev_ch2[ 1518 ] 1603.28
# ++++++
# n= 41
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 90
# G_point= 1554
# Elev_ch2= 1554
# G_point/tm_size 17.266666666666666
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 86
# M= 1548
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1548
# Elev_ch2[ 1548 ] 1603.166
# Elev_ch2[ 1553 ] 1603.252
# ++++++
# n= 42
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 98
# G_point= 1516
# Elev_ch2= 1516
# G_point/tm_size 15.46938775510204
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 94
# M= 1504
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1504
# Elev_ch2[ 1504 ] 1603.043
# Elev_ch2[ 1515 ] 1603.133
# ++++++
# n= 43
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 84
# G_point= 1554
# Elev_ch2= 1554
# G_point/tm_size 18.5
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 81
# M= 1539
# else
# itv2 = (G_point-1)- M = 14
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1603.015
# Elev_ch2[ 1553 ] 1603.062
# ++++++
# n= 44
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 107
# G_point= 1505
# Elev_ch2= 1505
# G_point/tm_size 14.065420560747663
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 100
# M= 1500
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1500
# Elev_ch2[ 1500 ] 1602.791
# Elev_ch2[ 1504 ] 1602.972
# ++++++
# n= 45
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 100
# G_point= 1552
# Elev_ch2= 1552
# G_point/tm_size 15.52
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 97
# M= 1552
# j == G_point j= 1552 Elev_ch2[ 1551 ]= 1602.871
# ++++++
# n= 46
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 96
# G_point= 1518
# Elev_ch2= 1518
# G_point/tm_size 15.8125
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 94
# M= 1504
# else
# itv2 = (G_point-1)- M = 13
# M = tm_size2 * itv = 1504
# Elev_ch2[ 1504 ] 1602.734
# Elev_ch2[ 1517 ] 1602.773
# ++++++
# n= 47
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 95
# G_point= 1559
# Elev_ch2= 1559
# G_point/tm_size 16.410526315789475
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1602.618
# Elev_ch2[ 1558 ] 1602.663
# ++++++
# n= 48
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 87
# G_point= 1514
# Elev_ch2= 1514
# G_point/tm_size 17.402298850574713
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 84
# M= 1512
# else
# itv2 = (G_point-1)- M = 1
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1602.562
# Elev_ch2[ 1513 ] 1602.647
# ++++++
# n= 49
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 64
# G_point= 1546
# Elev_ch2= 1546
# G_point/tm_size 24.15625
# itv=math.ceil(G_point/tm_size)
# itv= 25
# tm_size2=math.floor(G_point/itv)
# tm_size2= 61
# M= 1525
# else
# itv2 = (G_point-1)- M = 20
# M = tm_size2 * itv = 1525
# Elev_ch2[ 1525 ] 1602.526
# Elev_ch2[ 1545 ] 1602.663
# ++++++
# n= 50
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 85
# G_point= 1519
# Elev_ch2= 1519
# G_point/tm_size 17.870588235294118
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 84
# M= 1512
# else
# itv2 = (G_point-1)- M = 6
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1602.83
# Elev_ch2[ 1518 ] 1602.83
# ++++++
# n= 51
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 89
# G_point= 1549
# Elev_ch2= 1549
# G_point/tm_size 17.40449438202247
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 86
# M= 1548
# else
# itv2 = (G_point-1)- M = 0
# M = tm_size2 * itv = 1548
# Elev_ch2[ 1548 ] 1602.888
# Elev_ch2[ 1548 ] 1602.888
# ++++++
# n= 52
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 101
# G_point= 1515
# Elev_ch2= 1515
# G_point/tm_size 15.0
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# 1602.91 1602.9
# 1602.9034815875416
# ++++++
# n= 53
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 96
# G_point= 1547
# Elev_ch2= 1547
# G_point/tm_size 16.114583333333332
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# j == G_point j= 1547 Elev_ch2[ 1546 ]= 1602.756
# ++++++
# n= 54
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 106
# G_point= 1521
# Elev_ch2= 1521
# G_point/tm_size 14.349056603773585
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1515
# Elev_ch2[ 1515 ] 1602.656
# Elev_ch2[ 1520 ] 1602.712
# ++++++
# n= 55
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 105
# G_point= 1541
# Elev_ch2= 1541
# G_point/tm_size 14.676190476190476
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 102
# M= 1530
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1530
# Elev_ch2[ 1530 ] 1602.646
# Elev_ch2[ 1540 ] 1602.642
# ++++++
# n= 56
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 98
# G_point= 1531
# Elev_ch2= 1531
# G_point/tm_size 15.622448979591837
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1602.597
# Elev_ch2[ 1530 ] 1602.612
# ++++++
# n= 57
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 103
# G_point= 1559
# Elev_ch2= 1559
# G_point/tm_size 15.135922330097088
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 97
# M= 1552
# else
# itv2 = (G_point-1)- M = 6
# M = tm_size2 * itv = 1552
# Elev_ch2[ 1552 ] 1602.38
# Elev_ch2[ 1558 ] 1602.554
# ++++++
# n= 58
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 98
# G_point= 1525
# Elev_ch2= 1525
# G_point/tm_size 15.561224489795919
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1602.431
# Elev_ch2[ 1524 ] 1602.447
# ++++++
# n= 59
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 112
# G_point= 1552
# Elev_ch2= 1552
# G_point/tm_size 13.857142857142858
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1602.328
# Elev_ch2[ 1551 ] 1602.337
# ++++++
# n= 60
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 99
# G_point= 1531
# Elev_ch2= 1531
# G_point/tm_size 15.464646464646465
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1602.259
# Elev_ch2[ 1530 ] 1602.29
# ++++++
# n= 61
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 95
# G_point= 1559
# Elev_ch2= 1559
# G_point/tm_size 16.410526315789475
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1602.099
# Elev_ch2[ 1558 ] 1602.164
# ++++++
# n= 62
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 95
# G_point= 1522
# Elev_ch2= 1522
# G_point/tm_size 16.021052631578947
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 89
# M= 1513
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1513
# Elev_ch2[ 1513 ] 1602.001
# Elev_ch2[ 1521 ] 1602.107
# ++++++
# n= 63
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 95
# G_point= 1555
# Elev_ch2= 1555
# G_point/tm_size 16.36842105263158
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1601.919
# Elev_ch2[ 1554 ] 1601.983
# ++++++
# n= 64
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 108
# G_point= 1523
# Elev_ch2= 1523
# G_point/tm_size 14.101851851851851
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1515
# Elev_ch2[ 1515 ] 1601.713
# Elev_ch2[ 1522 ] 1601.965
# ++++++
# n= 65
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 104
# G_point= 1550
# Elev_ch2= 1550
# G_point/tm_size 14.903846153846153
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1601.886
# Elev_ch2[ 1549 ] 1601.886
# ++++++
# n= 66
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 100
# G_point= 1524
# Elev_ch2= 1524
# G_point/tm_size 15.24
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1601.661
# Elev_ch2[ 1523 ] 1601.788
# ++++++
# n= 67
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 93
# G_point= 1552
# Elev_ch2= 1552
# G_point/tm_size 16.688172043010752
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1601.708
# Elev_ch2[ 1551 ] 1601.703
# ++++++
# n= 68
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 113
# G_point= 1518
# Elev_ch2= 1518
# G_point/tm_size 13.43362831858407
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 108
# M= 1512
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1601.498
# Elev_ch2[ 1517 ] 1601.629
# ++++++
# n= 69
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 104
# G_point= 1549
# Elev_ch2= 1549
# G_point/tm_size 14.89423076923077
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1601.535
# Elev_ch2[ 1548 ] 1601.535
# ++++++
# n= 70
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 103
# G_point= 1524
# Elev_ch2= 1524
# G_point/tm_size 14.79611650485437
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1515
# Elev_ch2[ 1515 ] 1601.477
# Elev_ch2[ 1523 ] 1601.479
# ++++++
# n= 71
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 116
# G_point= 1553
# Elev_ch2= 1553
# G_point/tm_size 13.387931034482758
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 110
# M= 1540
# else
# itv2 = (G_point-1)- M = 12
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1601.243
# Elev_ch2[ 1552 ] 1601.389
# ++++++
# n= 72
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 114
# G_point= 1529
# Elev_ch2= 1529
# G_point/tm_size 13.412280701754385
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 109
# M= 1526
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1526
# Elev_ch2[ 1526 ] 1601.169
# Elev_ch2[ 1528 ] 1601.311
# ++++++
# n= 73
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 108
# G_point= 1553
# Elev_ch2= 1553
# G_point/tm_size 14.37962962962963
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1601.159
# Elev_ch2[ 1552 ] 1601.242
# ++++++
# n= 74
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 102
# G_point= 1518
# Elev_ch2= 1518
# G_point/tm_size 14.882352941176471
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 101
# M= 1515
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1515
# Elev_ch2[ 1515 ] 1601.168
# Elev_ch2[ 1517 ] 1601.168
# ++++++
# n= 75
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 108
# G_point= 1555
# Elev_ch2= 1555
# G_point/tm_size 14.398148148148149
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1600.937
# Elev_ch2[ 1554 ] 1601.077
# ++++++
# n= 76
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 110
# G_point= 1518
# Elev_ch2= 1518
# G_point/tm_size 13.8
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 108
# M= 1512
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1601.026
# Elev_ch2[ 1517 ] 1601.038
# ++++++
# n= 77
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 98
# G_point= 1553
# Elev_ch2= 1553
# G_point/tm_size 15.846938775510203
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 97
# M= 1552
# else
# itv2 = (G_point-1)- M = 0
# M = tm_size2 * itv = 1552
# Elev_ch2[ 1552 ] 1600.924
# Elev_ch2[ 1552 ] 1600.924
# ++++++
# n= 78
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 96
# G_point= 1526
# Elev_ch2= 1526
# G_point/tm_size 15.895833333333334
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 5
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1600.859
# Elev_ch2[ 1525 ] 1600.859
# ++++++
# n= 79
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 99
# G_point= 1562
# Elev_ch2= 1562
# G_point/tm_size 15.777777777777779
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 97
# M= 1552
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1552
# Elev_ch2[ 1552 ] 1600.796
# Elev_ch2[ 1561 ] 1600.786
# ++++++
# n= 80
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 101
# G_point= 1523
# Elev_ch2= 1523
# G_point/tm_size 15.07920792079208
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 95
# M= 1520
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1520
# Elev_ch2[ 1520 ] 1600.539
# Elev_ch2[ 1522 ] 1600.69
# ++++++
# n= 81
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 93
# G_point= 1560
# Elev_ch2= 1560
# G_point/tm_size 16.774193548387096
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 91
# M= 1547
# else
# itv2 = (G_point-1)- M = 12
# M = tm_size2 * itv = 1547
# Elev_ch2[ 1547 ] 1600.621
# Elev_ch2[ 1559 ] 1600.644
# ++++++
# n= 82
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 110
# G_point= 1520
# Elev_ch2= 1520
# G_point/tm_size 13.818181818181818
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 108
# M= 1512
# else
# itv2 = (G_point-1)- M = 7
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1600.556
# Elev_ch2[ 1519 ] 1600.553
# ++++++
# n= 83
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 75
# G_point= 1558
# Elev_ch2= 1558
# G_point/tm_size 20.773333333333333
# itv=math.ceil(G_point/tm_size)
# itv= 21
# tm_size2=math.floor(G_point/itv)
# tm_size2= 74
# M= 1554
# else
# itv2 = (G_point-1)- M = 3
# M = tm_size2 * itv = 1554
# Elev_ch2[ 1554 ] 1600.499
# Elev_ch2[ 1557 ] 1600.499
# ++++++
# n= 84
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 86
# G_point= 1522
# Elev_ch2= 1522
# G_point/tm_size 17.697674418604652
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 84
# M= 1512
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1600.407
# Elev_ch2[ 1521 ] 1600.414
# ++++++
# n= 85
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 80
# G_point= 1558
# Elev_ch2= 1558
# G_point/tm_size 19.475
# itv=math.ceil(G_point/tm_size)
# itv= 20
# tm_size2=math.floor(G_point/itv)
# tm_size2= 77
# M= 1540
# else
# itv2 = (G_point-1)- M = 17
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1600.233
# Elev_ch2[ 1557 ] 1600.323
# ++++++
# n= 86
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 91
# G_point= 1523
# Elev_ch2= 1523
# G_point/tm_size 16.736263736263737
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 89
# M= 1513
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1513
# Elev_ch2[ 1513 ] 1600.285
# Elev_ch2[ 1522 ] 1600.29
# ++++++
# n= 87
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 81
# G_point= 1563
# Elev_ch2= 1563
# G_point/tm_size 19.296296296296298
# itv=math.ceil(G_point/tm_size)
# itv= 20
# tm_size2=math.floor(G_point/itv)
# tm_size2= 78
# M= 1560
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1560
# Elev_ch2[ 1560 ] 1600.062
# Elev_ch2[ 1562 ] 1600.206
# ++++++
# n= 88
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 110
# G_point= 1524
# Elev_ch2= 1524
# G_point/tm_size 13.854545454545455
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 108
# M= 1512
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1600.022
# Elev_ch2[ 1523 ] 1600.153
# ++++++
# n= 89
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 103
# G_point= 1557
# Elev_ch2= 1557
# G_point/tm_size 15.116504854368932
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 97
# M= 1552
# else
# itv2 = (G_point-1)- M = 4
# M = tm_size2 * itv = 1552
# Elev_ch2[ 1552 ] 1599.736
# Elev_ch2[ 1556 ] 1600.064
# ++++++
# n= 90
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 109
# G_point= 1525
# Elev_ch2= 1525
# G_point/tm_size 13.990825688073395
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 108
# M= 1512
# else
# itv2 = (G_point-1)- M = 12
# M = tm_size2 * itv = 1512
# Elev_ch2[ 1512 ] 1600.047
# Elev_ch2[ 1524 ] 1600.047
# ++++++
# n= 91
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 109
# G_point= 1559
# Elev_ch2= 1559
# G_point/tm_size 14.302752293577981
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 13
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1599.591
# Elev_ch2[ 1558 ] 1599.915
# ++++++
# n= 92
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 142
# G_point= 1520
# Elev_ch2= 1520
# G_point/tm_size 10.704225352112676
# itv=math.ceil(G_point/tm_size)
# itv= 11
# tm_size2=math.floor(G_point/itv)
# tm_size2= 138
# M= 1518
# else
# itv2 = (G_point-1)- M = 1
# M = tm_size2 * itv = 1518
# Elev_ch2[ 1518 ] 1599.775
# Elev_ch2[ 1519 ] 1599.871
# ++++++
# n= 93
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 118
# G_point= 1557
# Elev_ch2= 1557
# G_point/tm_size 13.194915254237289
# itv=math.ceil(G_point/tm_size)
# itv= 14
# tm_size2=math.floor(G_point/itv)
# tm_size2= 111
# M= 1554
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1554
# Elev_ch2[ 1554 ] 1599.401
# Elev_ch2[ 1556 ] 1599.8
# ++++++
# n= 94
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 136
# G_point= 1512
# Elev_ch2= 1512
# G_point/tm_size 11.117647058823529
# itv=math.ceil(G_point/tm_size)
# itv= 12
# tm_size2=math.floor(G_point/itv)
# tm_size2= 126
# M= 1512
# j == G_point j= 1512 Elev_ch2[ 1511 ]= 1599.387
# ++++++
# n= 95
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 110
# G_point= 1554
# Elev_ch2= 1554
# G_point/tm_size 14.127272727272727
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1599.224
# Elev_ch2[ 1553 ] 1599.642
# ++++++
# n= 96
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 92
# G_point= 1512
# Elev_ch2= 1512
# G_point/tm_size 16.434782608695652
# itv=math.ceil(G_point/tm_size)
# itv= 17
# tm_size2=math.floor(G_point/itv)
# tm_size2= 88
# M= 1496
# else
# itv2 = (G_point-1)- M = 15
# M = tm_size2 * itv = 1496
# Elev_ch2[ 1496 ] 1599.442
# Elev_ch2[ 1511 ] 1599.515
# ++++++
# n= 97
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 106
# G_point= 1555
# Elev_ch2= 1555
# G_point/tm_size 14.669811320754716
# itv=math.ceil(G_point/tm_size)
# itv= 15
# tm_size2=math.floor(G_point/itv)
# tm_size2= 103
# M= 1545
# else
# itv2 = (G_point-1)- M = 9
# M = tm_size2 * itv = 1545
# Elev_ch2[ 1545 ] 1599.439
# Elev_ch2[ 1554 ] 1599.501
# ++++++
# n= 98
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 80
# G_point= 1513
# Elev_ch2= 1513
# G_point/tm_size 18.9125
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 79
# M= 1501
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1501
# Elev_ch2[ 1501 ] 1599.429
# Elev_ch2[ 1512 ] 1599.429
# ++++++
# n= 99
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 83
# G_point= 1554
# Elev_ch2= 1554
# G_point/tm_size 18.72289156626506
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 81
# M= 1539
# else
# itv2 = (G_point-1)- M = 14
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1599.356
# Elev_ch2[ 1553 ] 1599.36
# ++++++
# n= 100
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 82
# G_point= 1510
# Elev_ch2= 1510
# G_point/tm_size 18.414634146341463
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 79
# M= 1501
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1501
# Elev_ch2[ 1501 ] 1599.174
# Elev_ch2[ 1509 ] 1599.277
# ++++++
# n= 101
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 86
# G_point= 1548
# Elev_ch2= 1548
# G_point/tm_size 18.0
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 86
# M= 1548
# 1599.18 1599.198
# 1599.180826835781
# ++++++
# n= 102
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 88
# G_point= 1506
# Elev_ch2= 1506
# G_point/tm_size 17.113636363636363
# itv=math.ceil(G_point/tm_size)
# itv= 18
# tm_size2=math.floor(G_point/itv)
# tm_size2= 83
# M= 1494
# else
# itv2 = (G_point-1)- M = 11
# M = tm_size2 * itv = 1494
# Elev_ch2[ 1494 ] 1599.007
# Elev_ch2[ 1505 ] 1599.137
# ++++++
# n= 103
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 82
# G_point= 1548
# Elev_ch2= 1548
# G_point/tm_size 18.878048780487806
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 81
# M= 1539
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1539
# Elev_ch2[ 1539 ] 1599.053
# Elev_ch2[ 1547 ] 1599.053
# ++++++
# n= 104
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 78
# G_point= 1501
# Elev_ch2= 1501
# G_point/tm_size 19.243589743589745
# itv=math.ceil(G_point/tm_size)
# itv= 20
# tm_size2=math.floor(G_point/itv)
# tm_size2= 75
# M= 1500
# else
# itv2 = (G_point-1)- M = 0
# M = tm_size2 * itv = 1500
# Elev_ch2[ 1500 ] 1598.964
# Elev_ch2[ 1500 ] 1598.964
# ++++++
# n= 105
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 78
# G_point= 1551
# Elev_ch2= 1551
# G_point/tm_size 19.884615384615383
# itv=math.ceil(G_point/tm_size)
# itv= 20
# tm_size2=math.floor(G_point/itv)
# tm_size2= 77
# M= 1540
# else
# itv2 = (G_point-1)- M = 10
# M = tm_size2 * itv = 1540
# Elev_ch2[ 1540 ] 1598.891
# Elev_ch2[ 1550 ] 1598.891
# ++++++
# n= 106
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 83
# G_point= 1504
# Elev_ch2= 1504
# G_point/tm_size 18.120481927710845
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 79
# M= 1501
# else
# itv2 = (G_point-1)- M = 2
# M = tm_size2 * itv = 1501
# Elev_ch2[ 1501 ] 1598.774
# Elev_ch2[ 1503 ] 1598.837
# ++++++
# n= 107
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 77
# G_point= 1550
# Elev_ch2= 1550
# G_point/tm_size 20.12987012987013
# itv=math.ceil(G_point/tm_size)
# itv= 21
# tm_size2=math.floor(G_point/itv)
# tm_size2= 73
# M= 1533
# else
# itv2 = (G_point-1)- M = 16
# M = tm_size2 * itv = 1533
# Elev_ch2[ 1533 ] 1598.699
# Elev_ch2[ 1549 ] 1598.784
# ++++++
# n= 108
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 83
# G_point= 1510
# Elev_ch2= 1510
# G_point/tm_size 18.19277108433735
# itv=math.ceil(G_point/tm_size)
# itv= 19
# tm_size2=math.floor(G_point/itv)
# tm_size2= 79
# M= 1501
# else
# itv2 = (G_point-1)- M = 8
# M = tm_size2 * itv = 1501
# Elev_ch2[ 1501 ] 1598.606
# Elev_ch2[ 1509 ] 1598.743
# ++++++
# n= 109
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 99
# G_point= 1550
# Elev_ch2= 1550
# G_point/tm_size 15.656565656565656
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 96
# M= 1536
# else
# itv2 = (G_point-1)- M = 13
# M = tm_size2 * itv = 1536
# Elev_ch2[ 1536 ] 1598.6
# Elev_ch2[ 1549 ] 1598.69
# ++++++
# n= 110
# ++++++
# "tm_size" means the number of GNSS points
# tm_size= 96
# G_point= 1503
# Elev_ch2= 1503
# G_point/tm_size 15.65625
# itv=math.ceil(G_point/tm_size)
# itv= 16
# tm_size2=math.floor(G_point/itv)
# tm_size2= 93
# M= 1488
# else
# itv2 = (G_point-1)- M = 14
# M = tm_size2 * itv = 1488
# Elev_ch2[ 1488 ] 1598.561
# Elev_ch2[ 1502 ] 1598.614

# %%
#for n in np.arange(0,N,1): 
#    plt.plot(Elev_ch4[n][:])

#match the direction of the GPR measurement
#for n in np.arange(0,N,1): 
#plt.plot(Elev_ch4[10][:],"bo")
#plt.plot(Elev_ch5[3][:],"ro")
#plt.plot(Elev_ch4[3][:],"b")

plt.plot(Elev_ch4[0][:],"r")
plt.plot(Elev_ch4[1][:],"b")
plt.plot(Elev_ch4[2][:],"g")

#plt.plot(Elev_ch5[2][:],"r")

#plt.plot(Elev_ch4[10][:])

#plt.plot(np.flipud(Elev_ch4[10][:]),"r")
#plt.plot(Elev_ch4[11][:])

# %%
#plt.plot(GNSS_tm[3][0:size[3]],"bo")
plt.plot(GNSS[6][0:size[6]], "r")
plt.plot(GNSS[5][0:size[5]], "r")
plt.plot(GNSS[4][0:size[4]], "r")

plt.plot(GNSS[3][0:size[3]], "r")
plt.plot(GNSS[2][0:size[2]], "r")
plt.plot(GNSS[1][0:size[2]], "r")

#plt.plot(np.flipud(GNSS[1][0:size[1]]))

# %%
f1=open("3Dmorph_GPR_flipped.txt",'a')
np.savetxt(f1,Elev_ch4.T,"%9.3f", newline="\n")
SN = "_1" # section number

f2=open("3Dmorph_section_GPR"+SN+".txt",'a')
for n in np.arange(0,3,1):
    np.savetxt(f2,Elev_ch4[n][:],"%9.3f", newline="\n")

# %%
#insert last element
#s_03 = np.append(s_02,s_02[-1]+16)

#print("")
#print(s_03)
#print("s_03 size=",np.size(s_03))
#print("The reason why we need s_03 is that s_02 do not reflect the last part of the Elev_ch03")

# %%
"""
j=s_02[-1]+1
#print(j)
#print(G_point)
#print(G_point-j)
n = G_point - j

print(Elev_ch3[j-1])
print(Elev_ch3[j-n])
print(Elev_ch3[j-1] - Elev_ch3[j-n])

print("")
for i in np.arange(j,G_point,1): 
#        print(i)
        if(Elev_ch3[j-1]-Elev_ch3[j-n] > 0):
            Elev_ch3[i] = Elev_ch3[j-n] + ((i-j)*0.05) *(Elev_ch3[j-1] - Elev_ch3[j-n])/(0.05*n)
            
            
        elif(Elev_ch3[j-1]-Elev_ch3[j-n] < 0):
#            print(j-n)
            Elev_ch3[i] = Elev_ch3[j-n] + ((i-j)*0.05) *(Elev_ch3[j-1] - Elev_ch3[j-n])/(0.05*n)
#            print(Elev_ch3[j-n], Elev_ch3[j],j)
        #print(i, Elev_ch3[i])
"""
